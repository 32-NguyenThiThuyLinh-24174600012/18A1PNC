# %%
import json

# Đối tượng Python (kiểu dict)
person = {
    "name": "Nguyen Van A",
    "age": 25,
    "city": "Hanoi",
    "skills": ["Python", "Data Analysis", "Machine Learning"]
}

# Chuyển đối tượng Python sang chuỗi JSON
json_string = json.dumps(person, ensure_ascii=False, indent=4)

print("✅ Chuỗi JSON sau khi chuyển đổi:")
print(json_string)

# In ra tất cả các giá trị trong đối tượng gốc
print("\n📋 Tất cả các giá trị trong đối tượng Python:")
for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# ✅ Chuỗi JSON sau khi chuyển đổi:
# {
#     "name": "Nguyen Van A",
#     "age": 25,
#     "city": "Hanoi",
#     "skills": [
#         "Python",
#         "Data Analysis",
#         "Machine Learning"
#     ]
# }
#
# 📋 Tất cả các giá trị trong đối tượng Python:
# name: Nguyen Van A
# age: 25
# city: Hanoi
# skills: ['Python', 'Data Analysis', 'Machine Learning']
